# %%
#Random Forest
import pickle
filename = "final-modal-RF-classification.sav"

# %%
load_model = pickle.load(open('final-modal-RF-classification.sav','rb'))
result = load_model.predict([[15624510,19,19000,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print(result)
# Out:
# [0]
